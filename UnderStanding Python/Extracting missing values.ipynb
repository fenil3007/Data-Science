# %%
import pandas as pd
import  numpy as np

# %%
data = pd.read_excel("_Project-Spreadsheet---for-Data-Validation.xlsx")

# %%
print(data)
# Out:
#                                Task  Asignee        READY Review By This Date
# 0                  Review C5M3 plan     Tony  IN PROGRESS          2020-03-13
# 1         Map out next week's goals   Ximena  IN PROGRESS          2020-03-19
# 2            Review weekly invoices    Sally        READY          2020-04-02
# 3       Send out stakeholder emails    Erica        READY          2020-04-10
# 4      Follow up on customer emails   Ayanna        READY          2020-04-17
# 5       Prepare presentation for VP   Hallie          NaN          2020-04-24
# 6        Schedule next team meeting     Tony          NaN          2020-04-27
# 7         Map out next week's goals   Ximena          NaN          2020-05-18
# 8            Review weekly invoices    Sally          NaN          2020-05-25
# 9       Send out stakeholder emails    Erica          NaN          2020-04-24
# 10      Set next week's team agenda   Ayanna    NOT READY          2020-04-27
# ...

# %%
data
# Out:
#                                Task  Asignee        READY Review By This Date
# 0                  Review C5M3 plan     Tony  IN PROGRESS          2020-03-13
# 1         Map out next week's goals   Ximena  IN PROGRESS          2020-03-19
# 2            Review weekly invoices    Sally        READY          2020-04-02
# 3       Send out stakeholder emails    Erica        READY          2020-04-10
# 4      Follow up on customer emails   Ayanna        READY          2020-04-17
# 5       Prepare presentation for VP   Hallie          NaN          2020-04-24
# 6        Schedule next team meeting     Tony          NaN          2020-04-27
# 7         Map out next week's goals   Ximena          NaN          2020-05-18
# 8            Review weekly invoices    Sally          NaN          2020-05-25
# 9       Send out stakeholder emails    Erica          NaN          2020-04-24
# 10      Set next week's team agenda   Ayanna    NOT READY          2020-04-27
# ...

# %%
data.head(6)
# Out:
#                            Task Asignee        READY Review By This Date
# 0              Review C5M3 plan    Tony  IN PROGRESS          2020-03-13
# 1     Map out next week's goals  Ximena  IN PROGRESS          2020-03-19
# 2        Review weekly invoices   Sally        READY          2020-04-02
# 3   Send out stakeholder emails   Erica        READY          2020-04-10
# 4  Follow up on customer emails  Ayanna        READY          2020-04-17
# 5   Prepare presentation for VP  Hallie          NaN          2020-04-24

# %%
data.shape
# Out:
# (44, 4)

# %%
data.describe()
# Out:
#                  Review By This Date
# count                             44
# mean   2020-06-25 01:38:10.909090816
# min              2020-03-13 00:00:00
# 25%              2020-04-26 06:00:00
# 50%              2020-05-18 00:00:00
# 75%              2020-08-29 18:00:00
# max              2020-12-30 00:00:00

# %%
(data[3]==NaN).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ...

# %%
data = pd.read_csv("diabetes.csv")

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
(data==0).sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
columns=list(data)

# %%
(data[columns[1:6]]==0).sum()
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
data[columns[1:6]]=(data[columns[1:6]]).replace(0,np.nan)

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
(data[columns[1:6]]==0).sum()
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64

# %%
(data[columns[1:6]]==np.nan).sum()
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64

# %%
data.shape
# Out:
# (768, 9)

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# 6              3     78.0           50.0           32.0     88.0  31.0
# 8              2    197.0           70.0           45.0    543.0  30.5
# 13             1    189.0           60.0           23.0    846.0  30.1
# ..           ...      ...            ...            ...      ...   ...
# 753            0    181.0           88.0           44.0    510.0  43.3
# 755            1    128.0           88.0           39.0    110.0  36.5
# 760            2     88.0           58.0           26.0     16.0  28.4
# 763           10    101.0           76.0           48.0    180.0  32.9
# 765            5    121.0           72.0           23.0    112.0  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %%
data.shape
# Out:
# (392, 9)
