# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Wine Quality Dataset.csv")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 937

# %%
data.drop(data.duplicated(),axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data.drop(data.duplicated(),axis=0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
data.shape
# Out:
# (4898, 12)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4898, step=1)

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# # visualization

# %%
data.hist("fixed acidity",bins = 30)
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>]], dtype=object)

# %%
# histogram using seaborn

# %%
plt.figure(figsize  = (11,6))

sns.histplot(data=data , x = "fixed acidity",color = "orange",edgecolor = "purple",alpha = 0.9,bins = 20,label = "fixed acidity")
plt.title("Histogram of fixed acidity")
plt.xlabel("fixed acidity")
plt.ylabel("count")
plt.legend()
plt.show()

# %%
import math

# %%
data['fixed acidity'].mean()
# Out:
# 6.854787668436097

# %%
data['fixed acidity'].mode()
# Out:
# 0    6.8
# Name: fixed acidity, dtype: float64

# %%
data['fixed acidity'].median()
# Out:
# 6.8

# %%
plt.figure(figsize  = (11,6))

sns.dhistplot(data["fixed acidity"],color = "orange",edgecolor = "purple",alpha = 0.9,bins = 20,label = "fixed acidity")
plt.title("Histogram of fixed acidity")
plt.xlabel("fixed acidity")
plt.ylabel("count")
plt.vlines(data['fixed acidity'].mean(),ymin = 0,ymax = 4000,colors = "blue",label = "mean")
plt.vlines(data['fixed acidity'].median(),ymin = 0,ymax = 4000,colors = "red",label = "median")

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 3
#       1 plt.figure(figsize  = (11,6))
# ----> 3 sns.dhistplot(data["fixed acidity"],color = "orange",edgecolor = "purple",alpha = 0.9,bins = 20,label = "fixed acidity")
#       4 plt.title("Histogram of fixed acidity")
#       5 plt.xlabel("fixed acidity")
#
# AttributeError: module 'seaborn' has no attribute 'dhistplot'

# %%
plt.figure(figsize  = (11,6))

sns.distplot(data["volatile acidity"],color = "orange")
plt.title("Distplot of volatile acidity")
plt.xlabel("volatile acidity")
plt.ylabel("density")

plt.legend()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8580\777184602.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["volatile acidity"],color = "orange")
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data['volatile acidity'].skew()
# Out:
# 1.5769795029952025

# %%
data['volatile acidity'].mean()
# Out:
# 0.27824111882400976

# %%
data['volatile acidity'].median()
# Out:
# 0.26

# %%
data['volatile acidity'].mode()
# Out:
# 0    0.28
# Name: volatile acidity, dtype: float64

# %%
plt.figure(figsize  = (11,6))

sns.distplot(data["volatile acidity"],color = "orange")
plt.title("Distplot of volatile acidity")
plt.xlabel("volatile acidity")
plt.ylabel("density")
plt.vlines(data['volatile acidity'].mean(),ymin = 0 , ymax = 5,colors  = 'red',label = 'mean')
plt.vlines(data['volatile acidity'].median(),ymin = 0,ymax=5,colors= 'blue',label = 'median')
plt.legend()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8580\3455538355.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["volatile acidity"],color = "orange")

# %%
plt.figure(figsize =(12,7))

sns.histplot(data = data, x ='citric acid',color = 'red',edgecolor ='white',label= 'citric acid',alpha=0.8,bins =20)
plt.title("Histogram of citric acid")
plt.xlabel("Citric acid")
plt.ylabel("Count")
plt.vlines(data['citric acid'].mean(),ymin=0,ymax = 2000,colors="black",label = 'mean')
plt.vlines(data['citric acid'].median(),ymin=0,ymax = 2000,colors="blue",label = 'median')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(13,9))

sns.distplot(data['citric acid'],color = "blue")
plt.xlabel('Citric acid')
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8580\923746226.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['citric acid'],color = "blue")

# %%
plt.figure(figsize=(13,9))

sns.distplot(data['residual sugar'],color = "blue")
plt.xlabel('residual sugar')
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8580\3320721044.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['residual sugar'],color = "blue")

# %%
plt.figure(figsize=(13,9))

sns.distplot(data['chlorides'],color = "blue")
plt.xlabel('chlorides')
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8580\265061098.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['chlorides'],color = "blue")

# %%
plt.figure(figsize=(13,9))

sns.distplot(data['free sulfur dioxide'],color = "blue")
plt.xlabel('free sulfur dioxide')
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8580\2100787848.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['free sulfur dioxide'],color = "blue")

# %%
plt.figure(figsize=(13,9))

sns.distplot(data['total sulfur dioxide'],color = "blue")
plt.xlabel('total sulfur dioxide')
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8580\2075838019.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['total sulfur dioxide'],color = "blue")

# %%
# count plot of quality

# %%
plt.figure(figsize= (11,6))

sns.countplot(data['quality'])

plt.title("count plot of quality")

plt.xlabel('Quality')
plt.ylabel('Counts')
plt.show()

# %%
plt.figure(figsize= (11,6))
sns.countplot(data['quality'])
plt.title("count plot of quality")
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %%
data['quality'].value_counts().index[0]
# Out:
# 6

# %%
# create rep_acid which contains acid types and their mean values

# %%
rep_acid  = pd.Series(index = ['fixed acidity','volatile acidity','citric acid','quality'],
                     data = [data['fixed acidity'].mean(),data['volatile acidity'].mean(),data['citric acid'].mean(),data['quality'].value_counts().index[0]])

# %%
rep_acid
# Out:
# fixed acidity       6.854788
# volatile acidity    0.278241
# citric acid         0.334192
# quality             6.000000
# dtype: float64
